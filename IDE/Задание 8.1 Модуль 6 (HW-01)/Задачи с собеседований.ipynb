# %% [markdown]
# # Задание 1.
# Найти пересечение без дубликатов

# %% [markdown]
# # Задание 2.
# Найти минимум и максимум

# %% [markdown]
# # Задание 3.
# Найти медиану

# %% [markdown]
# # Задание №4
# Преобразовать строку в число

# %% [markdown]
# # Задание №5
# (бонусная, не оценивается)
# Разложить факториал на простые множители

# %% [markdown]
# # Задание №6
# (бонусная, не оценивается)
# Заменить дублирующиеся буквы
